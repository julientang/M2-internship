# %%
import os 
import sys

import healpy as hp
import matplotlib.pyplot as plt
import numpy as np

import toast

# %%
import scipy.signal as si

# %%
import pysm3
import pysm3.units as usm

# %%
import astropy.units as u

# %%
env = toast.utils.Environment.get()
comm, procs, rank = toast.get_world()
nthread = os.environ["OMP_NUM_THREADS"]

# %%
mem = toast.utils.memreport(msg="(whole node)", comm=comm, silent=False)
# Out:
# Memory usage (whole node)
#        total :  503.138 GB
#    available :  276.071 GB
#      percent :   45.100 %
#      percent :   45.200 %  (after GC)
#         used :  156.368 GB
#         used :  156.539 GB (after GC)
#         free :  216.029 GB
#       active :   39.333 GB
#     inactive :  148.593 GB
#     inactive :  148.765 GB (after GC)
#      buffers :  232.793 MB
#       cached :  130.514 GB
#       shared :   54.173 GB
#         slab :   65.147 GB

# %% [markdown]
# 0. Create a template CMB map (sky signal)

# %%
NSIDE = 64
lmax = 2*NSIDE

# %%
##Create a polarized CMB map
sky = pysm3.Sky(nside=NSIDE, preset_strings=["c1"])

# %%
sky.components
map_30GHz = sky.get_emission(30*u.GHz)
map_30GHz = map_30GHz.to(usm.K_CMB, equivalencies=usm.cmb_equivalencies(100*u.GHz))

# %%
map_30GHz.shape
# Out:
# (3, 49152)

# %%
rGC = hp.rotator.Rotator(coord=['G','C'])  # Transforms galactic to equatorial coordinates
map_30GHz_GC = np.array([rGC.rotate_map_pixel(map) for map in map_30GHz])
hp.mollview(map_30GHz_GC[0], title="CMB I map (equatorial)", unit=map_30GHz.unit)

# %%
hp.write_map(filename='file_CMB_30GHz.FITS',m = map_30GHz_GC, coord = 'C',overwrite=True)
# Out:
# setting the output map dtype to [dtype('float64'), dtype('float64'), dtype('float64')]

# %%
map2 = hp.read_map(filename='file_CMB_30GHz.FITS',field=None)

# %%
map2.shape
# Out:
# (3, 49152)

# %%
hp.mollview((map2-map_30GHz_GC)[0], min = -1e-13,max = 1e-13)

# %% [markdown]
# 1. Start by creating a focalplane with a sample rate and number of detectors

# %%
focalplane = toast.instrument.Focalplane(sample_rate=10*u.Hz#,thinfp=256
                                        )
##One fourth of total detectors in the focalplane
## For S4, sample rate ~10-100

# %%
with toast.io.H5File("focalplane_SAT3_SAT_f030.h5", "r", comm=comm, force_serial=True) as f:
            focalplane.load_hdf5(f.handle, comm=comm)

# %% [markdown]
# Print focalplane information

# %%
focalplane
# Out:
# <Focalplane: 252 detectors, sample_rate = 10.0 Hz, FOV = 29.77320077597548 deg, detectors = [029_000_SAT_f030_A .. 040_011_SAT_f030_B]>

# %% [markdown]
# Define the schedule, site and telescope

# %%
schedule = toast.schedule.GroundSchedule()
schedule.read("POLE_DEEP-169-7.txt", comm=comm)
# Out:
# TOAST INFO: Loading schedule from POLE_DEEP-169-7.txt
# TOAST INFO: Loaded 1 scans from POLE_DEEP-169-7.txt totaling 84.0 minutes.

# %% [markdown]
# Print schedule information

# %%
schedule
# Out:
# <GroundSchedule site=SOUTH_POLE at -89.991 deg, -44.65 deg, 2843.0 m telescope SAT with 1 scans
#   <GroundScan 'POLE_DEEP' at 2027-05-28T15:00:00+00:00 with El = 54.1 deg, Az 288.19 deg -- 358.87 deg>
# >

# %% [markdown]
# Print telescope information

# %%
site = toast.instrument.GroundSite(
        schedule.site_name,
        schedule.site_lat,
        schedule.site_lon,
        schedule.site_alt,
        weather=None,
    )
telescope = toast.instrument.Telescope(
        "My_telescope", focalplane=focalplane, site=site
    )

# %%
telescope
# Out:
# <Telescope 'My_telescope': uid = 3533178314, site = <GroundSite 'SOUTH_POLE' : uid = 588178429, lon = -44.64999999999998 deg, lat = -89.991 deg, alt = 2842.9999999993684 m, weather = None>, focalplane = <Focalplane: 252 detectors, sample_rate = 10.0 Hz, FOV = 29.77320077597548 deg, detectors = [029_000_SAT_f030_A .. 040_011_SAT_f030_B]>>

# %% [markdown]
# We can have multiple groups for parallel computing (start with one). Create a Data Instance and simulate a ground observation operator.

# %%
toast_comm = toast.Comm(world=comm, groupsize=1)

# %%
data = toast.Data(comm=toast_comm)

# %%
sim_ground = toast.ops.SimGround(name="sim_ground", 
                                 weather="south_pole", 
                                 detset_key="pixel", 
                                 telescope = telescope, 
                                 schedule = schedule
                                ) ##simulate motion of the boresight

# %%
sim_ground
# Out:
# <SimGround
#   API = 0 # Internal interface version for this operator
#   azimuth = azimuth # Observation shared key for Azimuth
#   boresight_azel = boresight_azel # Observation shared key for boresight AZ/EL
#   boresight_radec = boresight_radec # Observation shared key for boresight RA/DEC
#   det_data = signal # Observation detdata key to initialize
#   det_data_units = K # Output units if creating detector data
#   det_flags = flags # Observation detdata key for flags to initialize
#   detset_key = pixel # If specified, use this column of the focalplane detector_data to group detectors
#   distribute_time = False # Distribute observation data along the time axis rather than detector axis
#   el_mod_amplitude = 1.0 deg # Range of elevation modulation
#   el_mod_rate = 0.0 Hz # Modulate elevation continuously at this rate
#   el_mod_sine = False # Modulate elevation with a sine wave instead of a triangle wave
#   el_mod_step = 0.0 deg # Amount to step elevation after each left-right scan pair
#   elevation = elevation # Observation shared key for Elevation
#   elnod_end = False # Perform an el-nod after the scan
#   elnod_every_scan = False # Perform el nods every scan
#   elnod_interval = elnod # Interval name for elnods
#   elnod_mask = 8 # Bit mask to raise elevation nod flags with
#   elnod_start = False # Perform an el-nod before the scan
#   elnods = [] # List of relative el_nods
#   enabled = True # If True, this class instance is marked as enabled
#   fix_rate_on_sky = True # If True, `scan_rate_az` is given in sky coordinates and azimuthal rate on mount will be adjusted to meet it.  If False, `scan_rate_az` is used as the mount azimuthal rate.
#   hwp_angle = None # Observation shared key for HWP angle
#   hwp_rpm = None # The rate (in RPM) of the HWP rotation
#   hwp_step = None # For stepped HWP, the angle of each step
#   hwp_step_time = None # For stepped HWP, the time between steps
#   kernel_implementation = 0 # Which kernel implementation to use (DEFAULT, COMPILED, NUMPY, JAX).
#   max_pwv = None # Maximum PWV for the simulated weather.
#   median_weather = False # Use median weather parameters instead of sampling from the distributions
#   name = sim_ground # The 'name' of this class instance
#   position = position # Observation shared key for position
#   randomize_phase = False # If True, the Constant Elevation Scan will begin at a randomized phase.
#   realization = 0 # The realization index
#   scan_accel_az = 1.0 deg / s2 # Mount scanning rate acceleration for turnarounds
#   scan_accel_el = 1.0 deg / s2 # Mount elevation rate acceleration.
#   scan_cosecant_modulation = False # Modulate the scan rate according to 1/sin(az) for uniform depth
#   scan_leftright_interval = scan_leftright # Interval name for left to right scans
#   scan_rate_az = 1.0 deg / s # The sky or mount azimuth scanning rate.  See `fix_rate_on_sky`
#   scan_rate_el = 1.0 deg / s # The sky elevation scanning rate
#   scan_rightleft_interval = scan_rightleft # Interval name for right to left scans
#   scanning_interval = scanning # Interval name for scanning
#   schedule = <GroundSchedule site=SOUTH_POLE at -89.991 deg, -44.65 deg, 2843.0 m telescope SAT with 1 scans
#   <GroundScan 'POLE_DEEP' at 2027-05-28T15:00:00+00:00 with El = 54.1 deg, Az 288.19 deg -- 358.87 deg>
# > # Instance of a GroundSchedule
#   session_split_key = None # Focalplane key for splitting into observations
#   shared_flags = flags # Observation shared key for common flags
#   sun_angle_min = 90.0 deg # Minimum angular distance for the scan and the Sun
#   sun_close_distance = 45.0 deg # 'Sun close' flagging distance
#   sun_close_interval = sun_close # Interval name for times when the sun is close
#   sun_close_mask = 32 # Bit mask to raise Sun close flags with
#   sun_up_interval = sun_up # Interval name for times when the sun is up
#   sun_up_mask = 16 # Bit mask to raise Sun up flags with
#   telescope = <Telescope 'My_telescope': uid = 3533178314, site = <GroundSite 'SOUTH_POLE' : uid = 588178429, lon = -44.64999999999998 deg, lat = -89.991 deg, alt = 2842.9999999993684 m, weather = None>, focalplane = <Focalplane: 252 detectors, sample_rate = 10.0 Hz, FOV = 29.77320077597548 deg, detectors = [029_000_SAT_f030_A .. 040_011_SAT_f030_B]>> # This must be an instance of a Telescope
#   throw_interval = throw # Interval name for scan + turnaround intervals
#   throw_leftright_interval = throw_leftright # Interval name for left to right scans + turnarounds
#   throw_rightleft_interval = throw_rightleft # Interval name for right to left scans + turnarounds
#   times = times # Observation shared key for timestamps
#   track_azimuth = False # If True, the azimuth throw is continually adjusted to center the field.
#   turn_leftright_interval = turn_leftright # Interval name for turnarounds after left to right scans
#   turn_rightleft_interval = turn_rightleft # Interval name for turnarounds after right to left scans
#   turnaround_interval = turnaround # Interval name for turnarounds
#   turnaround_mask = 4 # Bit mask to raise turnaround flags with
#   use_ephem = True # Use PyEphem to convert between horizontal and equatorial systems
#   use_qpoint = False # Use qpoint to convert between horizontal and equatorial systems
#   velocity = velocity # Observation shared key for velocity
#   weather = south_pole # Name of built-in weather site (e.g. 'atacama', 'south_pole') or path to HDF5 file
# >

# %%
sim_ground.apply(data)

# %%
data.obs[0]
## Session associated to weather simulation, not individual optic tubes
# Out:
# <Observation
#   name = 'POLE_DEEP-169-7'
#   uid = '2008944542'  group has a single process (no MPI)
#   telescope = <Telescope 'My_telescope': uid = 3533178314, site = <GroundSite 'SOUTH_POLE' : uid = 588178429, lon = -44.64999999999998 deg, lat = -89.991 deg, alt = 2842.9999999993684 m, weather = <SimWeather : 'south_pole', year = 2027, month = 4, hour = 15, site UID = 588178429, realization = 0, median = False)>, focalplane = <Focalplane: 252 detectors, sample_rate = 10.0 Hz, FOV = 29.77320077597548 deg, detectors = [029_000_SAT_f030_A .. 040_011_SAT_f030_B]>>
#   session = <Session 'POLE_DEEP-169-7': uid = 1708650531, start = 2027-05-28 15:00:00+00:00, end = 2027-05-28 16:23:59.900000+00:00>
#   scan_el = 54.1 deg
#   scan_min_az = -1.2787014485740134 rad
#   scan_max_az = 6.263463086632051 rad
#   scan_min_el = 0.9442231253289323 rad
#   scan_max_el = 0.9442231253289323 rad
#   50400 total samples (50400 local)
#   shared:  <SharedDataManager
#     times (column): shape=(50400,), dtype=float64
#     position (column): shape=(50400, 3), dtype=float64
#     velocity (column): shape=(50400, 3), dtype=float64
#     azimuth (column): shape=(50400,), dtype=float64
#     elevation (column): shape=(50400,), dtype=float64
#     boresight_azel (column): shape=(50400, 4), dtype=float64
#     boresight_radec (column): shape=(50400, 4), dtype=float64
#     flags (column): shape=(50400,), dtype=uint8>
#   detdata:  <DetDataManager 252 local detectors, 50400 samples
#     signal: shape=(252, 50400), dtype=float64, units='K'
#     flags: shape=(252, 50400), dtype=uint8, units=''>
#   intervals:  <IntervalsManager 13 lists
#   throw_leftright: 57 intervals
#   throw_rightleft: 56 intervals
#   throw: 113 intervals
#   scan_leftright: 57 intervals
#   turn_leftright: 56 intervals
#   scan_rightleft: 56 intervals
#   turn_rightleft: 56 intervals
#   elnod: 0 intervals
#   scanning: 113 intervals
#   turnaround: 112 intervals
#   sun_up: 0 intervals
#   sun_close: 0 intervals>
# >

# %%
ob = data.obs[0]

# %%
ob.detdata.create(name = 'atmosphere',units = u.K)
ob.detdata.create(name = 'noise',units = u.K)

# %%
ob.detdata
# Out:
# <DetDataManager 252 local detectors, 50400 samples
#     signal: shape=(252, 50400), dtype=float64, units='K'
#     flags: shape=(252, 50400), dtype=uint8, units=''
#     atmosphere: shape=(252, 50400), dtype=float64, units='K'
#     noise: shape=(252, 50400), dtype=float64, units='K'>

# %% [markdown]
# 2. Noise simulation

# %%
noise_model = toast.ops.DefaultNoiseModel()
sim_noise = toast.ops.SimNoise() ###Need to instantiate Noise Model

# %%
sim_noise.det_data= 'noise'

# %%
sim_noise
# Out:
# <SimNoise
#   API = 0 # Internal interface version for this operator
#   component = 0 # The noise component index
#   det_data = noise # Observation detdata key for accumulating noise timestreams
#   det_data_units = K # Output units if creating detector data
#   enabled = True # If True, this class instance is marked as enabled
#   kernel_implementation = 0 # Which kernel implementation to use (DEFAULT, COMPILED, NUMPY, JAX).
#   name = SimNoise # The 'name' of this class instance
#   noise_model = noise_model # Observation key containing the noise model
#   realization = 0 # The noise realization index
#   serial = True # Use legacy serial implementation instead of batched
#   times = times # Observation shared key for timestamps
# >

# %%
noise_model.apply(data) ## Read detector noise from the focalplane

# %%
data
# Out:
# <Data with 1 Observations:
# <Observation
#   name = 'POLE_DEEP-169-7'
#   uid = '2008944542'  group has a single process (no MPI)
#   telescope = <Telescope 'My_telescope': uid = 3533178314, site = <GroundSite 'SOUTH_POLE' : uid = 588178429, lon = -44.64999999999998 deg, lat = -89.991 deg, alt = 2842.9999999993684 m, weather = <SimWeather : 'south_pole', year = 2027, month = 4, hour = 15, site UID = 588178429, realization = 0, median = False)>, focalplane = <Focalplane: 252 detectors, sample_rate = 10.0 Hz, FOV = 29.77320077597548 deg, detectors = [029_000_SAT_f030_A .. 040_011_SAT_f030_B]>>
#   session = <Session 'POLE_DEEP-169-7': uid = 1708650531, start = 2027-05-28 15:00:00+00:00, end = 2027-05-28 16:23:59.900000+00:00>
#   scan_el = 54.1 deg
#   scan_min_az = -1.2787014485740134 rad
#   scan_max_az = 6.263463086632051 rad
#   scan_min_el = 0.9442231253289323 rad
#   scan_max_el = 0.9442231253289323 rad
#   noise_model = <AnalyticNoise model with 252 detectors>
#   50400 total samples (50400 local)
#   shared:  <SharedDataManager
#     times (column): shape=(50400,), dtype=float64
#     position (column): shape=(50400, 3), dtype=float64
#     velocity (column): shape=(50400, 3), dtype=float64
#     azimuth (column): shape=(50400,), dtype=float64
#     elevation (column): shape=(50400,), dtype=float64
#     boresight_azel (column): shape=(50400, 4), dtype=float64
#     boresight_radec (column): shape=(50400, 4), dtype=float64
#     flags (column): shape=(50400,), dtype=uint8>
#   detdata:  <DetDataManager 252 local detectors, 50400 samples
#     signal: shape=(252, 50400), dtype=float64, units='K'
#     flags: shape=(252, 50400), dtype=uint8, units=''
#     atmosphere: shape=(252, 50400), dtype=float64, units='K'
#     noise: shape=(252, 50400), dtype=float64, units='K'>
#   intervals:  <IntervalsManager 13 lists
#   throw_leftright: 57 intervals
#   throw_rightleft: 56 intervals
#   throw: 113 intervals
#   scan_leftright: 57 intervals
#   turn_leftright: 56 intervals
#   scan_rightleft: 56 intervals
#   turn_rightleft: 56 intervals
#   elnod: 0 intervals
#   scanning: 113 intervals
#   turnaround: 112 intervals
#   sun_up: 0 intervals
#   sun_close: 0 intervals>
# >
# Metadata:
# {}
# >

# %%
sim_noise.apply(data)

# %%
plt.plot(ob.shared["times"][0:600],ob.detdata["noise"][0][0:600],".") ##Detdata has several data, signal is under "signal", detdata is a 2D array
plt.xlabel('$t$ in s')
plt.ylabel('Measured intensity in $ K_{CMB}$')
plt.title('1 min of Simulated detector noise for Detector 0')
plt.show()

# %% [markdown]
# 3. Create a pointing operator to reconstruct maps from TOD. Compute associated weights, pixelization and binning operator $\rightarrow$ mapmaking operator.

# %% [markdown]
# Switch from Healpix to Car?

# %%
pointing = toast.ops.PointingDetectorSimple() ##boresight pointing into detector frame (RA/DEC by default)
weights = toast.ops.StokesWeights(detector_pointing = pointing,mode = "IQU")
pixels = toast.ops.PixelsHealpix(detector_pointing = pointing, nside = 64)

# %%
#pixels_CAR= toast.ops.PixelsCar(detector_pointing = pointing, nside = 64)

# %% [markdown]
# We want to solve the map making problem using the following equations :
# \begin{equation}
#     \begin{aligned}
#         \mathbf{m} &= \mathbf{\left(P^T C_n ^{-1} P\right)^{-1}P^T C_n ^{-1}(y-Fa)}\\
#         \mathbf{\left(F^T C_n^{-1} Z F+C_a^{-1}\right)a} &= \mathbf{F^T C_n^{-1} Zy}\\
#         \text{with } \mathbf{Z} &\equiv \mathbf{I-P\left(P^T C_n ^{-1} P\right)^{-1}P^T C_n ^{-1}}
#     \end{aligned}
# \end{equation}

# %%
pointing
# Out:
# <PointingDetectorSimple
#   API = 0 # Internal interface version for this operator
#   boresight = boresight_radec # Observation shared key for boresight
#   coord_in = None # The input boresight coordinate system ('C', 'E', 'G')
#   coord_out = None # The output coordinate system ('C', 'E', 'G')
#   det_mask = 1 # Bit mask value for per-detector flagging
#   enabled = True # If True, this class instance is marked as enabled
#   kernel_implementation = 0 # Which kernel implementation to use (DEFAULT, COMPILED, NUMPY, JAX).
#   name = PointingDetectorSimple # The 'name' of this class instance
#   quats = quats # Observation detdata key for output quaternions
#   shared_flag_mask = 1 # Bit mask value for optional flagging
#   shared_flags = flags # Observation shared key for telescope flags to use
#   view = None # Use this view of the data in all observations
# >

# %% [markdown]
# Choose baseline length $t_{base} \sim 1/f_{knee}$, to select modes dominant over white noise :

# %%
step_0 = 4*u.second
step_0
# Out:
# <Quantity 4. s>

# %%
templates = [toast.templates.Offset(name="baselines", step_time = step_0)]

# %%
templates
# Out:
# [<Offset
#    data = None # This must be an instance of a Data class (or None)
#    debug_plots = None # If not None, make debugging plots in this directory
#    det_data = signal # Observation detdata key for the timestream data
#    det_data_units = K # Desired units of detector data
#    det_flag_mask = 7 # Bit mask value for solver flags
#    det_flags = flags # Observation detdata key for solver flags to use
#    det_mask = 1 # Bit mask value for per-detector flagging
#    enabled = True # If True, this class instance is marked as enabled
#    good_fraction = 0.5 # Fraction of unflagged samples needed to keep a given offset amplitude
#    kernel_implementation = 0 # Which kernel implementation to use (DEFAULT, COMPILED, NUMPY, JAX).
#    name = baselines # The 'name' of this class instance
#    noise_model = None # Observation key containing the optional noise model
#    precond_width = 20 # Preconditioner width in terms of offsets / baselines
#    step_time = 4.0 s # Time per baseline step
#    times = times # Observation shared key for timestamps
#    use_noise_prior = False # Use detector PSDs to build the noise prior and preconditioner
#    view = None # Use this view of the data in all observations
#  >]

# %%
template_matrix = toast.ops.TemplateMatrix(templates=templates)

# %%
template_matrix
# Out:
# <TemplateMatrix
#   API = 0 # Internal interface version for this operator
#   amplitudes = None # Data key for template amplitudes
#   det_data = None # Observation detdata key for the timestream data
#   det_data_units = K # Output units if creating detector data
#   det_flag_mask = 7 # Bit mask value for detector sample flagging
#   det_flags = flags # Observation detdata key for flags to use
#   det_mask = 7 # Bit mask value for per-detector flagging
#   enabled = True # If True, this class instance is marked as enabled
#   kernel_implementation = 0 # Which kernel implementation to use (DEFAULT, COMPILED, NUMPY, JAX).
#   name = TemplateMatrix # The 'name' of this class instance
#   templates = [<Offset
#   data = None # This must be an instance of a Data class (or None)
#   debug_plots = None # If not None, make debugging plots in this directory
#   det_data = signal # Observation detdata key for the timestream data
#   det_data_units = K # Desired units of detector data
#   det_flag_mask = 7 # Bit mask value for solver flags
#   det_flags = flags # Observation detdata key for solver flags to use
#   det_mask = 1 # Bit mask value for per-detector flagging
#   enabled = True # If True, this class instance is marked as enabled
#   good_fraction = 0.5 # Fraction of unflagged samples needed to keep a given offset amplitude
#   kernel_implementation = 0 # Which kernel implementation to use (DEFAULT, COMPILED, NUMPY, JAX).
#   name = baselines # The 'name' of this class instance
#   noise_model = None # Observation key containing the optional noise model
#   precond_width = 20 # Preconditioner width in terms of offsets / baselines
#   step_time = 4.0 s # Time per baseline step
#   times = times # Observation shared key for timestamps
#   use_noise_prior = False # Use detector PSDs to build the noise prior and preconditioner
#   view = None # Use this view of the data in all observations
# >] # This should be a list of Template instances
#   transpose = False # If True, apply the transpose.
#   view = None # Use this view of the data in all observations
# >

# %% [markdown]
# Create a scan operator to scan an input Healpix map :

# %%
scan_map = toast.ops.ScanHealpixMap(name="scan_healpix_map", file='file_CMB_30GHz.FITS',pixel_pointing = pixels, stokes_weights = weights)
scan_map.det_data = 'signal'

# %%
scan_map.apply(data)
data
# Out:
# TOAST INFO: Pixel data in file_CMB_30GHz.FITS does not have TUNIT1 key.  Assuming 'K'.
# <Data with 1 Observations:
# <Observation
#   name = 'POLE_DEEP-169-7'
#   uid = '2008944542'  group has a single process (no MPI)
#   telescope = <Telescope 'My_telescope': uid = 3533178314, site = <GroundSite 'SOUTH_POLE' : uid = 588178429, lon = -44.64999999999998 deg, lat = -89.991 deg, alt = 2842.9999999993684 m, weather = <SimWeather : 'south_pole', year = 2027, month = 4, hour = 15, site UID = 588178429, realization = 0, median = False)>, focalplane = <Focalplane: 252 detectors, sample_rate = 10.0 Hz, FOV = 29.77320077597548 deg, detectors = [029_000_SAT_f030_A .. 040_011_SAT_f030_B]>>
#   session = <Session 'POLE_DEEP-169-7': uid = 1708650531, start = 2027-05-28 15:00:00+00:00, end = 2027-05-28 16:23:59.900000+00:00>
#   scan_el = 54.1 deg
#   scan_min_az = -1.2787014485740134 rad
#   scan_max_az = 6.263463086632051 rad
#   scan_min_el = 0.9442231253289323 rad
#   scan_max_el = 0.9442231253289323 rad
#   noise_model = <AnalyticNoise model with 252 detectors>
#   50400 total samples (50400 local)
#   shared:  <SharedDataManager
#     times (column): shape=(50400,), dtype=float64
#     position (column): shape=(50400, 3), dtype=float64
#     velocity (column): shape=(50400, 3), dtype=float64
#     azimuth (column): shape=(50400,), dtype=float64
#     elevation (column): shape=(50400,), dtype=float64
#     boresight_azel (column): shape=(50400, 4), dtype=float64
#     boresight_radec (column): shape=(50400, 4), dtype=float64
#     flags (column): shape=(50400,), dtype=uint8>
#   detdata:  <DetDataManager 252 local detectors, 50400 samples
#     signal: shape=(252, 50400), dtype=float64, units='K'
#     flags: shape=(252, 50400), dtype=uint8, units=''
#     atmosphere: shape=(252, 50400), dtype=float64, units='K'
#     noise: shape=(252, 50400), dtype=float64, units='K'
#     quats: shape=(1, 50400, 4), dtype=float64, units=''
#     pixels: shape=(1, 50400), dtype=int64, units=''
#     weights: shape=(1, 50400, 3), dtype=float64, units=''>
#   intervals:  <IntervalsManager 13 lists
#   throw_leftright: 57 intervals
#   throw_rightleft: 56 intervals
#   throw: 113 intervals
#   scan_leftright: 57 intervals
#   turn_leftright: 56 intervals
#   scan_rightleft: 56 intervals
#   turn_rightleft: 56 intervals
#   elnod: 0 intervals
#   scanning: 113 intervals
#   turnaround: 112 intervals
#   sun_up: 0 intervals
#   sun_close: 0 intervals>
# >
# Metadata:
# {'pixel_dist': <PixelDistribution 49152 pixels, 16 submaps, submap size = 3072>}
# >

# %%
plt.plot(ob.shared["times"][0:600],ob.detdata["signal"][0][0:600],".") ##Detdata has several data, signal is under "signal", detdata is a 2D array
plt.xlabel('$t$ in s')
plt.ylabel('Measured intensity in $ K_{CMB}$')
plt.title('1 min of CMB for Detector 0')
plt.show()

# %% [markdown]
# Create horizontal pointing

# %%
hpointing = toast.ops.PointingDetectorSimple(boresight = 'boresight_azel')

# %%
hpointing
# Out:
# <PointingDetectorSimple
#   API = 0 # Internal interface version for this operator
#   boresight = boresight_azel # Observation shared key for boresight
#   coord_in = None # The input boresight coordinate system ('C', 'E', 'G')
#   coord_out = None # The output coordinate system ('C', 'E', 'G')
#   det_mask = 1 # Bit mask value for per-detector flagging
#   enabled = True # If True, this class instance is marked as enabled
#   kernel_implementation = 0 # Which kernel implementation to use (DEFAULT, COMPILED, NUMPY, JAX).
#   name = PointingDetectorSimple # The 'name' of this class instance
#   quats = quats # Observation detdata key for output quaternions
#   shared_flag_mask = 1 # Bit mask value for optional flagging
#   shared_flags = flags # Observation shared key for telescope flags to use
#   view = None # Use this view of the data in all observations
# >

# %% [markdown]
# 4. Atmosphere simulation

# %%
sim_atmosphere = toast.ops.SimAtmosphere(detector_pointing=hpointing, detector_weights= weights, det_data='atmosphere')

# %%
sim_atmosphere.cache_dir = 'atmosphere'

# %% [markdown]
# Add cache directory to save time

# %%
sim_atmosphere.apply(data)

# %%
data.obs
# Out:
# [<Observation
#    name = 'POLE_DEEP-169-7'
#    uid = '2008944542'  group has a single process (no MPI)
#    telescope = <Telescope 'My_telescope': uid = 3533178314, site = <GroundSite 'SOUTH_POLE' : uid = 588178429, lon = -44.64999999999998 deg, lat = -89.991 deg, alt = 2842.9999999993684 m, weather = <SimWeather : 'south_pole', year = 2027, month = 4, hour = 15, site UID = 588178429, realization = 0, median = False)>, focalplane = <Focalplane: 252 detectors, sample_rate = 10.0 Hz, FOV = 29.77320077597548 deg, detectors = [029_000_SAT_f030_A .. 040_011_SAT_f030_B]>>
#    session = <Session 'POLE_DEEP-169-7': uid = 1708650531, start = 2027-05-28 15:00:00+00:00, end = 2027-05-28 16:23:59.900000+00:00>
#    scan_el = 54.1 deg
#    scan_min_az = -1.2787014485740134 rad
#    scan_max_az = 6.263463086632051 rad
#    scan_min_el = 0.9442231253289323 rad
#    scan_max_el = 0.9442231253289323 rad
#    noise_model = <AnalyticNoise model with 252 detectors>
#    50400 total samples (50400 local)
#    shared:  <SharedDataManager
#      times (column): shape=(50400,), dtype=float64
#      position (column): shape=(50400, 3), dtype=float64
#      velocity (column): shape=(50400, 3), dtype=float64
#      azimuth (column): shape=(50400,), dtype=float64
#      elevation (column): shape=(50400,), dtype=float64
#      boresight_azel (column): shape=(50400, 4), dtype=float64
#      boresight_radec (column): shape=(50400, 4), dtype=float64
#      flags (column): shape=(50400,), dtype=uint8>
#    detdata:  <DetDataManager 252 local detectors, 50400 samples
#      signal: shape=(252, 50400), dtype=float64, units='K'
#      flags: shape=(252, 50400), dtype=uint8, units=''
#      atmosphere: shape=(252, 50400), dtype=float64, units='K'
#      noise: shape=(252, 50400), dtype=float64, units='K'
#      quats: shape=(1, 50400, 4), dtype=float64, units=''
#      pixels: shape=(1, 50400), dtype=int64, units=''
#      weights: shape=(1, 50400, 3), dtype=float64, units=''>
#    intervals:  <IntervalsManager 13 lists
#    throw_leftright: 57 intervals
#    throw_rightleft: 56 intervals
#    throw: 113 intervals
#    scan_leftright: 57 intervals
#    turn_leftright: 56 intervals
#    scan_rightleft: 56 intervals
#    turn_rightleft: 56 intervals
#    elnod: 0 intervals
#    scanning: 113 intervals
#    turnaround: 112 intervals
#    sun_up: 0 intervals
#    sun_close: 0 intervals>
#  >]

# %%
data
# Out:
# <Data with 1 Observations:
# <Observation
#   name = 'POLE_DEEP-169-7'
#   uid = '2008944542'  group has a single process (no MPI)
#   telescope = <Telescope 'My_telescope': uid = 3533178314, site = <GroundSite 'SOUTH_POLE' : uid = 588178429, lon = -44.64999999999998 deg, lat = -89.991 deg, alt = 2842.9999999993684 m, weather = <SimWeather : 'south_pole', year = 2027, month = 4, hour = 15, site UID = 588178429, realization = 0, median = False)>, focalplane = <Focalplane: 252 detectors, sample_rate = 10.0 Hz, FOV = 29.77320077597548 deg, detectors = [029_000_SAT_f030_A .. 040_011_SAT_f030_B]>>
#   session = <Session 'POLE_DEEP-169-7': uid = 1708650531, start = 2027-05-28 15:00:00+00:00, end = 2027-05-28 16:23:59.900000+00:00>
#   scan_el = 54.1 deg
#   scan_min_az = -1.2787014485740134 rad
#   scan_max_az = 6.263463086632051 rad
#   scan_min_el = 0.9442231253289323 rad
#   scan_max_el = 0.9442231253289323 rad
#   noise_model = <AnalyticNoise model with 252 detectors>
#   50400 total samples (50400 local)
#   shared:  <SharedDataManager
#     times (column): shape=(50400,), dtype=float64
#     position (column): shape=(50400, 3), dtype=float64
#     velocity (column): shape=(50400, 3), dtype=float64
#     azimuth (column): shape=(50400,), dtype=float64
#     elevation (column): shape=(50400,), dtype=float64
#     boresight_azel (column): shape=(50400, 4), dtype=float64
#     boresight_radec (column): shape=(50400, 4), dtype=float64
#     flags (column): shape=(50400,), dtype=uint8>
#   detdata:  <DetDataManager 252 local detectors, 50400 samples
#     signal: shape=(252, 50400), dtype=float64, units='K'
#     flags: shape=(252, 50400), dtype=uint8, units=''
#     atmosphere: shape=(252, 50400), dtype=float64, units='K'
#     noise: shape=(252, 50400), dtype=float64, units='K'
#     quats: shape=(1, 50400, 4), dtype=float64, units=''
#     pixels: shape=(1, 50400), dtype=int64, units=''
#     weights: shape=(1, 50400, 3), dtype=float64, units=''>
#   intervals:  <IntervalsManager 13 lists
#   throw_leftright: 57 intervals
#   throw_rightleft: 56 intervals
#   throw: 113 intervals
#   scan_leftright: 57 intervals
#   turn_leftright: 56 intervals
#   scan_rightleft: 56 intervals
#   turn_rightleft: 56 intervals
#   elnod: 0 intervals
#   scanning: 113 intervals
#   turnaround: 112 intervals
#   sun_up: 0 intervals
#   sun_close: 0 intervals>
# >
# Metadata:
# {'pixel_dist': <PixelDistribution 49152 pixels, 16 submaps, submap size = 3072>}
# >

# %%
ob.shared["times"].shape
# Out:
# (50400,)

# %%
ob.detdata["atmosphere"].shape
# Out:
# (252, 50400)

# %%
mean_atm = np.mean(ob.detdata["atmosphere"])
print(mean_atm)
# Out:
# 6.375452695763769

# %%
plt.plot(ob.shared["times"][0:600],ob.detdata["atmosphere"][0][0:600],".b") ##Detdata has several data, signal is under "signal", detdata is a 2D array

plt.xlabel('$t$ in s')
plt.ylabel('Measured intensity in $ K_{CMB}$')
plt.title('1 min of Atmosphere for detector 0')
plt.show()

# %%
plt.plot(ob.shared["times"][0:600],ob.detdata["signal"][0][0:600],".r",label = 'CMB') ##Detdata has several data, signal is under "signal", detdata is a 2D array
plt.plot(ob.shared["times"][0:600],ob.detdata["noise"][0][0:600],".g",label = 'Detector noise') ##Detdata has several data, signal is under "signal", detdata is a 2D array

plt.xlabel('$t$ in s')
plt.ylabel('Measured intensity in $ K_{CMB}$')
plt.legend(loc = 'best')
plt.title('1 min scan for detector 0 (in I)')
plt.show()

# %% [markdown]
# Add pair differences

# %% [markdown]
# Compute PSD to find $f_{knee}$

# %%
psd_detector = np.array([si.welch(TOD,fs = 10,nperseg=4096) for TOD in ob.detdata["noise"]])

# %%
plt.plot(psd_detector[1,0],psd_detector[1,1],".b") ##Detdata has several data, signal is under "signal", detdata is a 2D array
plt.xscale('log')
plt.yscale('log')

plt.xlabel('$f$ in Hz')
plt.title('PSD for first detector')
plt.show()

# %%
ob.detdata.create(name = 'contamination',units = u.K)
ob.detdata.create(name = 'full',units = u.K)

# %%
type(ob.detdata['contamination'][:,:])
# Out:
# numpy.ndarray

# %%
ob.detdata['contamination'][:,:] = ob.detdata['atmosphere'][:,:]+ob.detdata['noise'][:,:]
ob.detdata['full'][:,:] = ob.detdata['contamination'][:,:]+ob.detdata['signal'][:,:]

# %% [markdown]
# Recombine all TOD to form the total measured timestream

# %%
plt.plot(ob.shared["times"][0:600],ob.detdata["contamination"][0][0:600],".r",label = 'Atmosphere + noise') ##Detdata has several data, signal is under "signal", detdata is a 2D array
plt.plot(ob.shared["times"][0:600],ob.detdata["full"][0][0:600],".g",label = 'full') ##Detdata has several data, signal is under "signal", detdata is a 2D array

plt.xlabel('$t$ in s')
plt.ylabel('Measured intensity in $ K_{CMB}$')
plt.legend(loc = 'best')
plt.title('1 min scan for detector 0 (in I)')
plt.show()

# %% [markdown]
# How to center data in 0?
# Find the right average?
#
# How does the instrument adjust between detectors? Relative average level for different detectors?
#
# Use a 0-th order polynominial filter to remove average

# %%
def filter_0(obs, det_data):
    obs_arr = obs.detdata[det_data]
    obs_arr2 = np.zeros(obs_arr.shape)
    i = 0
    for detec in obs_arr:
        obs_arr2[i] = detec- np.mean(detec)
        i+=1
    obs.detdata[det_data][:,:]  = obs_arr2

# %%
filter_0(ob,'full')

# %%
for detdata in ["signal", "noise", "atmosphere", "contamination", "full"]:
    filter_0(ob,detdata)

# %%
#polyfilter = toast.ops.PolyFilter(name="polyfilter1D", order=0)
#polyfilter
#
#type(ob.intervals['throw'])
#
#polyfilter.view
#
#for detdata in ["signal", "noise", "atmosphere", "contamination", "total"]:
#    polyfilter.det_data=detdata
#    polyfilter.apply(data)

# %%
plt.plot(ob.shared["times"][0:600],ob.detdata["noise"][0][0:600],".r") ##Detdata has several data, signal is under "signal", detdata is a 2D array
plt.plot(ob.shared["times"][0:600],ob.detdata["atmosphere"][0][0:600],".b") ##Detdata has several data, signal is under "signal", detdata is a 2D array

plt.xlabel('$t$ in s')
plt.ylabel('Measured intensity in $ K_{CMB}$')
plt.title('1 minute of Noise and atmosphere after removing offset (Detector 1)')
plt.show()

# %%
psd_detector = np.array([si.welch(TOD,fs = 10,nperseg=4096) for TOD in ob.detdata["noise"]])
plt.plot(psd_detector[1,0],psd_detector[1,1],".b") ##Detdata has several data, signal is under "signal", detdata is a 2D array
plt.xscale('log')
plt.yscale('log')

plt.xlabel('$f$ in Hz')
plt.title('PSD for first detector noise')
plt.show()

# %%
psd_detector = np.array([si.welch(TOD,fs = 10,nperseg=4096) for TOD in ob.detdata["full"]])
plt.plot(psd_detector[1,0],psd_detector[1,1],".b") ##Detdata has several data, signal is under "signal", detdata is a 2D array
plt.xscale('log')
plt.yscale('log')

plt.xlabel('$f$ in Hz')
plt.title('PSD for first detector total signal')
plt.show()

# %% [markdown]
# For each TOD, create a corresponding Mampaker operator, in order to retrieve reconstructed maps independently.

# %%
binner = toast.ops.BinMap(pixel_pointing = pixels, stokes_weights = weights)
mapmaker = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix)

# %%
mapmaker.iter_max = 50
mapmaker.convergence = 1.0e-10
mapmaker.mc_mode = False

#mapmaker

#mapmaker.mc_root = 'root'

# %%
mapmaker.mc_mode
# Out:
# False

# %%
for detdata in ["signal", "noise", "atmosphere", "contamination", "full"]:
    binner.det_data=detdata
    mapmaker.binning= binner
    mapmaker.det_data=detdata
    mapmaker.output_dir = './'+detdata
    mapmaker.apply(data)
# Out:
# TOAST INFO: SolveAmplitudes begin building flags for solver
# TOAST INFO: SolveAmplitudes  finished flag building in 0.04 s
# TOAST INFO: SolveAmplitudes begin build of solver covariance
# TOAST INFO: SolveAmplitudes begin build of rcond flags
# TOAST INFO: SolveAmplitudes  finished build of solver covariance in 3.19 s
# TOAST INFO: SolveAmplitudes Solver flags cut 1007074 / 12700800 = 7.93% of samples
# TOAST INFO: SolveAmplitudes begin RHS calculation
# TOAST INFO: SolveAmplitudes  finished RHS calculation in 20.04 s
# TOAST INFO: SolveAmplitudes begin PCG solver
# TOAST INFO: MapMaker initial residual = 1644401038939.7085 in 4.40 s
# TOAST INFO: MapMaker iteration    0, relative residual = 4.667602e-03 in 3.76 s
# TOAST INFO: MapMaker iteration    1, relative residual = 1.970239e-03 in 3.73 s
# TOAST INFO: MapMaker iteration    2, relative residual = 1.682764e-03 in 4.32 s
# TOAST INFO: MapMaker iteration    3, relative residual = 9.776365e-04 in 3.67 s
# TOAST INFO: MapMaker iteration    4, relative residual = 5.174638e-04 in 3.45 s
# TOAST INFO: MapMaker iteration    5, relative residual = 2.694115e-04 in 3.45 s
# TOAST INFO: MapMaker iteration    6, relative residual = 1.156229e-04 in 3.40 s
# TOAST INFO: MapMaker iteration    7, relative residual = 5.256811e-05 in 3.40 s
# TOAST INFO: MapMaker iteration    8, relative residual = 2.380676e-05 in 3.50 s
# TOAST INFO: MapMaker iteration    9, relative residual = 1.014053e-05 in 4.22 s
# TOAST INFO: MapMaker iteration   10, relative residual = 6.048863e-06 in 3.34 s
# TOAST INFO: MapMaker iteration   11, relative residual = 4.226547e-06 in 3.44 s
# TOAST INFO: MapMaker iteration   12, relative residual = 4.066450e-06 in 3.47 s
# TOAST INFO: MapMaker iteration   13, relative residual = 3.376731e-06 in 4.25 s
# TOAST INFO: MapMaker iteration   14, relative residual = 2.352106e-06 in 3.35 s
# TOAST INFO: MapMaker iteration   15, relative residual = 1.322864e-06 in 3.44 s
# TOAST INFO: MapMaker iteration   16, relative residual = 6.740622e-07 in 3.44 s
# TOAST INFO: MapMaker iteration   17, relative residual = 4.415652e-07 in 4.54 s
# TOAST INFO: MapMaker iteration   18, relative residual = 2.404925e-07 in 3.54 s
# TOAST INFO: MapMaker iteration   19, relative residual = 1.565169e-07 in 3.54 s
# TOAST INFO: MapMaker iteration   20, relative residual = 1.407685e-07 in 3.56 s
# TOAST INFO: MapMaker iteration   21, relative residual = 9.292013e-08 in 3.43 s
# TOAST INFO: MapMaker iteration   22, relative residual = 6.321873e-08 in 3.45 s
# TOAST INFO: MapMaker iteration   23, relative residual = 5.335080e-08 in 3.42 s
# TOAST INFO: MapMaker iteration   24, relative residual = 3.631511e-08 in 3.47 s
# TOAST INFO: MapMaker iteration   25, relative residual = 2.170720e-08 in 3.49 s
# TOAST INFO: MapMaker iteration   26, relative residual = 1.573028e-08 in 3.50 s
# TOAST INFO: MapMaker iteration   27, relative residual = 8.993453e-09 in 3.44 s
# TOAST INFO: MapMaker iteration   28, relative residual = 4.422363e-09 in 3.40 s
# TOAST INFO: MapMaker iteration   29, relative residual = 2.499500e-09 in 3.45 s
# TOAST INFO: MapMaker iteration   30, relative residual = 1.603144e-09 in 3.52 s
# TOAST INFO: MapMaker iteration   31, relative residual = 1.032227e-09 in 3.47 s
# TOAST INFO: MapMaker iteration   32, relative residual = 6.405581e-10 in 3.50 s
# TOAST INFO: MapMaker iteration   33, relative residual = 4.661966e-10 in 3.52 s
# TOAST INFO: MapMaker iteration   34, relative residual = 3.090710e-10 in 3.52 s
# TOAST INFO: MapMaker iteration   35, relative residual = 2.172783e-10 in 3.47 s
# TOAST INFO: MapMaker iteration   36, relative residual = 1.360229e-10 in 3.45 s
# TOAST INFO: MapMaker iteration   37, relative residual = 6.743798e-11 in 3.53 s
# TOAST INFO: MapMaker PCG converged after   37 iterations and 140.25 s
# TOAST INFO: SolveAmplitudes  finished solver in 140.25 s
# TOAST INFO: MapMaker  finished template amplitude solve in 163.53 s
# TOAST INFO: MapMaker begin build of final binning covariance
# TOAST INFO: MapMaker  finished build of final covariance in 1.93 s
# TOAST INFO: Wrote ./signal/MapMaker_hits.fits in 0.01 s
# TOAST INFO: Wrote ./signal/MapMaker_rcond.fits in 0.01 s
# TOAST INFO: MapMaker begin map binning
# TOAST INFO: MapMaker  finished binning in 15.98 s
# TOAST INFO: Wrote ./signal/MapMaker_binmap.fits in 0.01 s
# TOAST INFO: MapMaker begin apply template amplitudes
# TOAST INFO: MapMaker  finished apply template amplitudes in 0.29 s
# TOAST INFO: MapMaker begin final map binning
# TOAST INFO: MapMaker  finished final binning in 15.79 s
# TOAST INFO: Wrote ./signal/MapMaker_map.fits in 0.01 s
# TOAST INFO: Wrote ./signal/MapMaker_cov.fits in 0.01 s
# TOAST INFO: MapMaker  finished output write in 0.03 s
# TOAST INFO: SolveAmplitudes begin building flags for solver
# TOAST INFO: SolveAmplitudes  finished flag building in 0.04 s
# TOAST INFO: SolveAmplitudes begin build of solver covariance
# TOAST INFO: SolveAmplitudes begin build of rcond flags
# TOAST INFO: SolveAmplitudes  finished build of solver covariance in 3.07 s
# TOAST INFO: SolveAmplitudes Solver flags cut 1007074 / 12700800 = 7.93% of samples
# TOAST INFO: SolveAmplitudes begin RHS calculation
# TOAST INFO: SolveAmplitudes  finished RHS calculation in 18.51 s
# TOAST INFO: SolveAmplitudes begin PCG solver
# TOAST INFO: MapMaker initial residual = 121430382097947.05 in 3.46 s
# TOAST INFO: MapMaker iteration    0, relative residual = 4.451468e-04 in 3.42 s
# TOAST INFO: MapMaker iteration    1, relative residual = 8.846839e-05 in 3.54 s
# TOAST INFO: MapMaker iteration    2, relative residual = 3.402223e-05 in 3.63 s
# TOAST INFO: MapMaker iteration    3, relative residual = 1.587405e-05 in 3.58 s
# TOAST INFO: MapMaker iteration    4, relative residual = 8.484662e-06 in 3.81 s
# TOAST INFO: MapMaker iteration    5, relative residual = 4.960673e-06 in 4.16 s
# TOAST INFO: MapMaker iteration    6, relative residual = 2.796703e-06 in 3.50 s
# TOAST INFO: MapMaker iteration    7, relative residual = 1.595155e-06 in 4.38 s
# TOAST INFO: MapMaker iteration    8, relative residual = 8.302341e-07 in 3.56 s
# TOAST INFO: MapMaker iteration    9, relative residual = 4.177957e-07 in 3.60 s
# TOAST INFO: MapMaker iteration   10, relative residual = 2.482507e-07 in 3.52 s
# TOAST INFO: MapMaker iteration   11, relative residual = 1.658060e-07 in 3.51 s
# TOAST INFO: MapMaker iteration   12, relative residual = 1.173285e-07 in 3.52 s
# TOAST INFO: MapMaker iteration   13, relative residual = 8.723216e-08 in 3.47 s
# TOAST INFO: MapMaker iteration   14, relative residual = 6.512080e-08 in 3.60 s
# TOAST INFO: MapMaker iteration   15, relative residual = 4.872844e-08 in 3.49 s
# TOAST INFO: MapMaker iteration   16, relative residual = 3.342539e-08 in 3.45 s
# TOAST INFO: MapMaker iteration   17, relative residual = 2.174522e-08 in 3.41 s
# TOAST INFO: MapMaker iteration   18, relative residual = 1.484677e-08 in 3.41 s
# TOAST INFO: MapMaker iteration   19, relative residual = 9.285868e-09 in 3.40 s
# TOAST INFO: MapMaker iteration   20, relative residual = 5.582552e-09 in 3.41 s
# TOAST INFO: MapMaker iteration   21, relative residual = 3.478738e-09 in 3.47 s
# TOAST INFO: MapMaker iteration   22, relative residual = 2.401601e-09 in 3.42 s
# TOAST INFO: MapMaker iteration   23, relative residual = 1.931326e-09 in 3.43 s
# TOAST INFO: MapMaker iteration   24, relative residual = 1.323903e-09 in 3.41 s
# TOAST INFO: MapMaker iteration   25, relative residual = 9.152835e-10 in 3.37 s
# TOAST INFO: MapMaker iteration   26, relative residual = 6.309056e-10 in 3.47 s
# TOAST INFO: MapMaker iteration   27, relative residual = 4.456774e-10 in 3.44 s
# TOAST INFO: MapMaker iteration   28, relative residual = 3.113169e-10 in 3.38 s
# TOAST INFO: MapMaker iteration   29, relative residual = 2.053834e-10 in 3.39 s
# TOAST INFO: MapMaker iteration   30, relative residual = 1.064201e-10 in 4.27 s
# TOAST INFO: MapMaker iteration   31, relative residual = 6.394559e-11 in 3.38 s
# TOAST INFO: MapMaker PCG converged after   31 iterations and 117.26 s
# TOAST INFO: SolveAmplitudes  finished solver in 117.26 s
# TOAST INFO: MapMaker  finished template amplitude solve in 138.88 s
# TOAST INFO: MapMaker begin build of final binning covariance
# TOAST INFO: MapMaker  finished build of final covariance in 1.78 s
# TOAST INFO: Wrote ./noise/MapMaker_hits.fits in 0.01 s
# TOAST INFO: Wrote ./noise/MapMaker_rcond.fits in 0.01 s
# TOAST INFO: MapMaker begin map binning
# TOAST INFO: MapMaker  finished binning in 15.35 s
# TOAST INFO: Wrote ./noise/MapMaker_binmap.fits in 0.01 s
# TOAST INFO: MapMaker begin apply template amplitudes
# TOAST INFO: MapMaker  finished apply template amplitudes in 0.26 s
# TOAST INFO: MapMaker begin final map binning
# TOAST INFO: MapMaker  finished final binning in 16.03 s
# TOAST INFO: Wrote ./noise/MapMaker_map.fits in 0.01 s
# TOAST INFO: Wrote ./noise/MapMaker_cov.fits in 0.01 s
# TOAST INFO: MapMaker  finished output write in 0.03 s
# TOAST INFO: SolveAmplitudes begin building flags for solver
# TOAST INFO: SolveAmplitudes  finished flag building in 0.04 s
# TOAST INFO: SolveAmplitudes begin build of solver covariance
# TOAST INFO: SolveAmplitudes begin build of rcond flags
# TOAST INFO: SolveAmplitudes  finished build of solver covariance in 3.06 s
# TOAST INFO: SolveAmplitudes Solver flags cut 1007074 / 12700800 = 7.93% of samples
# TOAST INFO: SolveAmplitudes begin RHS calculation
# TOAST INFO: SolveAmplitudes  finished RHS calculation in 17.71 s
# TOAST INFO: SolveAmplitudes begin PCG solver
# TOAST INFO: MapMaker initial residual = 1043788523490808.4 in 4.32 s
# TOAST INFO: MapMaker iteration    0, relative residual = 5.547999e-05 in 3.47 s
# TOAST INFO: MapMaker iteration    1, relative residual = 1.555151e-05 in 3.48 s
# TOAST INFO: MapMaker iteration    2, relative residual = 7.908881e-06 in 3.60 s
# TOAST INFO: MapMaker iteration    3, relative residual = 3.670551e-06 in 3.49 s
# TOAST INFO: MapMaker iteration    4, relative residual = 1.963104e-06 in 3.55 s
# TOAST INFO: MapMaker iteration    5, relative residual = 1.219395e-06 in 3.52 s
# TOAST INFO: MapMaker iteration    6, relative residual = 7.666628e-07 in 3.53 s
# TOAST INFO: MapMaker iteration    7, relative residual = 4.806886e-07 in 3.55 s
# TOAST INFO: MapMaker iteration    8, relative residual = 3.217120e-07 in 3.56 s
# TOAST INFO: MapMaker iteration    9, relative residual = 2.502966e-07 in 3.66 s
# TOAST INFO: MapMaker iteration   10, relative residual = 1.522549e-07 in 4.06 s
# TOAST INFO: MapMaker iteration   11, relative residual = 8.733585e-08 in 3.60 s
# TOAST INFO: MapMaker iteration   12, relative residual = 6.349146e-08 in 3.59 s
# TOAST INFO: MapMaker iteration   13, relative residual = 4.894081e-08 in 3.56 s
# TOAST INFO: MapMaker iteration   14, relative residual = 3.592072e-08 in 3.48 s
# TOAST INFO: MapMaker iteration   15, relative residual = 2.123977e-08 in 3.56 s
# TOAST INFO: MapMaker iteration   16, relative residual = 1.190168e-08 in 3.53 s
# TOAST INFO: MapMaker iteration   17, relative residual = 5.948768e-09 in 3.50 s
# TOAST INFO: MapMaker iteration   18, relative residual = 3.133019e-09 in 3.57 s
# TOAST INFO: MapMaker iteration   19, relative residual = 1.714539e-09 in 3.60 s
# TOAST INFO: MapMaker iteration   20, relative residual = 1.126609e-09 in 3.56 s
# TOAST INFO: MapMaker iteration   21, relative residual = 7.383553e-10 in 3.63 s
# TOAST INFO: MapMaker iteration   22, relative residual = 5.936124e-10 in 3.60 s
# TOAST INFO: MapMaker iteration   23, relative residual = 4.817270e-10 in 3.68 s
# TOAST INFO: MapMaker iteration   24, relative residual = 3.419376e-10 in 3.72 s
# TOAST INFO: MapMaker iteration   25, relative residual = 2.404166e-10 in 5.34 s
# TOAST INFO: MapMaker iteration   26, relative residual = 1.607509e-10 in 3.54 s
# TOAST INFO: MapMaker iteration   27, relative residual = 9.335746e-11 in 3.46 s
# TOAST INFO: MapMaker PCG converged after   27 iterations and 106.33 s
# TOAST INFO: SolveAmplitudes  finished solver in 106.34 s
# TOAST INFO: MapMaker  finished template amplitude solve in 127.15 s
# TOAST INFO: MapMaker begin build of final binning covariance
# TOAST INFO: MapMaker  finished build of final covariance in 1.86 s
# TOAST INFO: Wrote ./atmosphere/MapMaker_hits.fits in 0.01 s
# TOAST INFO: Wrote ./atmosphere/MapMaker_rcond.fits in 0.01 s
# TOAST INFO: MapMaker begin map binning
# TOAST INFO: MapMaker  finished binning in 16.60 s
# TOAST INFO: Wrote ./atmosphere/MapMaker_binmap.fits in 0.01 s
# TOAST INFO: MapMaker begin apply template amplitudes
# TOAST INFO: MapMaker  finished apply template amplitudes in 0.29 s
# TOAST INFO: MapMaker begin final map binning
# TOAST INFO: MapMaker  finished final binning in 16.00 s
# TOAST INFO: Wrote ./atmosphere/MapMaker_map.fits in 0.01 s
# TOAST INFO: Wrote ./atmosphere/MapMaker_cov.fits in 0.01 s
# TOAST INFO: MapMaker  finished output write in 0.03 s
# TOAST INFO: SolveAmplitudes begin building flags for solver
# TOAST INFO: SolveAmplitudes  finished flag building in 0.05 s
# TOAST INFO: SolveAmplitudes begin build of solver covariance
# TOAST INFO: SolveAmplitudes begin build of rcond flags
# TOAST INFO: SolveAmplitudes  finished build of solver covariance in 3.19 s
# TOAST INFO: SolveAmplitudes Solver flags cut 1007074 / 12700800 = 7.93% of samples
# TOAST INFO: SolveAmplitudes begin RHS calculation
# TOAST INFO: SolveAmplitudes  finished RHS calculation in 18.81 s
# TOAST INFO: SolveAmplitudes begin PCG solver
# TOAST INFO: MapMaker initial residual = 1169787608432830.0 in 3.47 s
# TOAST INFO: MapMaker iteration    0, relative residual = 9.944131e-05 in 3.49 s
# TOAST INFO: MapMaker iteration    1, relative residual = 2.518535e-05 in 3.47 s
# TOAST INFO: MapMaker iteration    2, relative residual = 1.118039e-05 in 3.55 s
# TOAST INFO: MapMaker iteration    3, relative residual = 5.303500e-06 in 4.09 s
# TOAST INFO: MapMaker iteration    4, relative residual = 2.953812e-06 in 3.76 s
# TOAST INFO: MapMaker iteration    5, relative residual = 1.807790e-06 in 3.43 s
# TOAST INFO: MapMaker iteration    6, relative residual = 1.088433e-06 in 3.52 s
# TOAST INFO: MapMaker iteration    7, relative residual = 6.375627e-07 in 3.45 s
# TOAST INFO: MapMaker iteration    8, relative residual = 3.631484e-07 in 3.46 s
# TOAST INFO: MapMaker iteration    9, relative residual = 2.502534e-07 in 3.46 s
# TOAST INFO: MapMaker iteration   10, relative residual = 1.736317e-07 in 3.52 s
# TOAST INFO: MapMaker iteration   11, relative residual = 1.071635e-07 in 3.52 s
# TOAST INFO: MapMaker iteration   12, relative residual = 7.653152e-08 in 3.57 s
# TOAST INFO: MapMaker iteration   13, relative residual = 5.900653e-08 in 3.54 s
# TOAST INFO: MapMaker iteration   14, relative residual = 4.618988e-08 in 3.45 s
# TOAST INFO: MapMaker iteration   15, relative residual = 3.074186e-08 in 3.43 s
# TOAST INFO: MapMaker iteration   16, relative residual = 1.694523e-08 in 3.45 s
# TOAST INFO: MapMaker iteration   17, relative residual = 8.788253e-09 in 3.48 s
# TOAST INFO: MapMaker iteration   18, relative residual = 4.492377e-09 in 3.42 s
# TOAST INFO: MapMaker iteration   19, relative residual = 2.373718e-09 in 3.55 s
# TOAST INFO: MapMaker iteration   20, relative residual = 1.379321e-09 in 3.63 s
# TOAST INFO: MapMaker iteration   21, relative residual = 8.474115e-10 in 3.77 s
# TOAST INFO: MapMaker iteration   22, relative residual = 6.143370e-10 in 3.39 s
# TOAST INFO: MapMaker iteration   23, relative residual = 4.989015e-10 in 3.46 s
# TOAST INFO: MapMaker iteration   24, relative residual = 3.737593e-10 in 3.44 s
# TOAST INFO: MapMaker iteration   25, relative residual = 2.994721e-10 in 3.45 s
# TOAST INFO: MapMaker iteration   26, relative residual = 2.317513e-10 in 3.48 s
# TOAST INFO: MapMaker iteration   27, relative residual = 1.591782e-10 in 3.39 s
# TOAST INFO: MapMaker iteration   28, relative residual = 1.072326e-10 in 3.47 s
# TOAST INFO: MapMaker iteration   29, relative residual = 6.472844e-11 in 3.52 s
# TOAST INFO: MapMaker PCG converged after   29 iterations and 109.07 s
# TOAST INFO: SolveAmplitudes  finished solver in 109.07 s
# TOAST INFO: MapMaker  finished template amplitude solve in 131.12 s
# TOAST INFO: MapMaker begin build of final binning covariance
# TOAST INFO: MapMaker  finished build of final covariance in 1.84 s
# TOAST INFO: Wrote ./contamination/MapMaker_hits.fits in 0.01 s
# TOAST INFO: Wrote ./contamination/MapMaker_rcond.fits in 0.01 s
# TOAST INFO: MapMaker begin map binning
# TOAST INFO: MapMaker  finished binning in 15.46 s
# TOAST INFO: Wrote ./contamination/MapMaker_binmap.fits in 0.01 s
# TOAST INFO: MapMaker begin apply template amplitudes
# TOAST INFO: MapMaker  finished apply template amplitudes in 0.26 s
# TOAST INFO: MapMaker begin final map binning
# TOAST INFO: MapMaker  finished final binning in 16.36 s
# TOAST INFO: Wrote ./contamination/MapMaker_map.fits in 0.01 s
# TOAST INFO: Wrote ./contamination/MapMaker_cov.fits in 0.01 s
# TOAST INFO: MapMaker  finished output write in 0.03 s
# TOAST INFO: SolveAmplitudes begin building flags for solver
# TOAST INFO: SolveAmplitudes  finished flag building in 0.04 s
# TOAST INFO: SolveAmplitudes begin build of solver covariance
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Cell In[78], line 6
#       4 mapmaker.det_data=detdata
#       5 mapmaker.output_dir = './'+detdata
# ----> 6 mapmaker.apply(data)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/timing.py:107, in function_timer_stackskip.<locals>.df(*args, **kwargs)
#     105 @wraps(f)
#     106 def df(*args, **kwargs):
# --> 107     return f(*args, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/operator.py:107, in Operator.apply(self, data, detectors, use_accel, **kwargs)
#      86 @function_timer_stackskip
#      87 def apply(self, data, detectors=None, use_accel=None, **kwargs):
#      88     """Run exec() and finalize().
#      89
#      90     This is a convenience wrapper that calls exec() exactly once with an optional
#    (...)
#     105
#     106     """
# --> 107     self.exec(data, detectors, use_accel=use_accel, **kwargs)
#     108     return self.finalize(data, use_accel=use_accel, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/timing.py:107, in function_timer_stackskip.<locals>.df(*args, **kwargs)
#     105 @wraps(f)
#     106 def df(*args, **kwargs):
# --> 107     return f(*args, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/operator.py:47, in Operator.exec(self, data, detectors, use_accel, **kwargs)
#      45 log = Logger.get()
#      46 if self.enabled:
# ---> 47     self._exec(
#      48         data,
#      49         detectors=detectors,
#      50         use_accel=use_accel,
#      51         **kwargs,
#      52     )
#      53 else:
#      54     if data.comm.world_rank == 0:
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/timing.py:81, in function_timer.<locals>.df(*args, **kwargs)
#      79 @wraps(f)
#      80 def df(*args, **kwargs):
# ---> 81     return f(*args, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/mapmaker.py:642, in MapMaker._exec(self, data, detectors, use_accel, **kwargs)
#     639 self._memreport.prefix = "Start of mapmaking"
#     640 self._memreport.apply(self._data, use_accel=self._use_accel)
# --> 642 template_amplitudes = self._fit_templates()
#     644 map_binning = self._prepare_binning()
#     646 self._build_pixel_covariance(map_binning)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/timing.py:81, in function_timer.<locals>.df(*args, **kwargs)
#      79 @wraps(f)
#      80 def df(*args, **kwargs):
# ---> 81     return f(*args, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/mapmaker.py:356, in MapMaker._fit_templates(self)
#     334 """Solve for template amplitudes"""
#     336 amplitudes_solve = SolveAmplitudes(
#     337     name=self.name,
#     338     det_data=self.det_data,
#    (...)
#     354     report_memory=self.report_memory,
#     355 )
# --> 356 amplitudes_solve.apply(
#     357     self._data, detectors=self._detectors, use_accel=self._use_accel
#     358 )
#     359 template_amplitudes = amplitudes_solve.amplitudes
#     361 self._log.info_rank(
#     362     f"{self._log_prefix}  finished template amplitude solve in",
#     363     comm=self._comm,
#     364     timer=self._timer,
#     365 )
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/timing.py:107, in function_timer_stackskip.<locals>.df(*args, **kwargs)
#     105 @wraps(f)
#     106 def df(*args, **kwargs):
# --> 107     return f(*args, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/operator.py:107, in Operator.apply(self, data, detectors, use_accel, **kwargs)
#      86 @function_timer_stackskip
#      87 def apply(self, data, detectors=None, use_accel=None, **kwargs):
#      88     """Run exec() and finalize().
#      89
#      90     This is a convenience wrapper that calls exec() exactly once with an optional
#    (...)
#     105
#     106     """
# --> 107     self.exec(data, detectors, use_accel=use_accel, **kwargs)
#     108     return self.finalize(data, use_accel=use_accel, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/timing.py:107, in function_timer_stackskip.<locals>.df(*args, **kwargs)
#     105 @wraps(f)
#     106 def df(*args, **kwargs):
# --> 107     return f(*args, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/operator.py:47, in Operator.exec(self, data, detectors, use_accel, **kwargs)
#      45 log = Logger.get()
#      46 if self.enabled:
# ---> 47     self._exec(
#      48         data,
#      49         detectors=detectors,
#      50         use_accel=use_accel,
#      51         **kwargs,
#      52     )
#      53 else:
#      54     if data.comm.world_rank == 0:
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/timing.py:81, in function_timer.<locals>.df(*args, **kwargs)
#      79 @wraps(f)
#      80 def df(*args, **kwargs):
# ---> 81     return f(*args, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/mapmaker_templates.py:1107, in SolveAmplitudes._exec(self, data, detectors, use_accel, **kwargs)
#    1103 self._timer.start()
#    1105 self._prepare_flagging(solve_pixels)
# -> 1107 self._get_pixel_covariance(solve_pixels, solve_weights)
#    1108 self._write_del(self.solver_hits_name)
#    1110 self._get_rcond_mask(scan_pipe)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/timing.py:81, in function_timer.<locals>.df(*args, **kwargs)
#      79 @wraps(f)
#      80 def df(*args, **kwargs):
# ---> 81     return f(*args, **kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/mapmaker_templates.py:876, in SolveAmplitudes._get_pixel_covariance(self, solve_pixels, solve_weights)
#     869     return
#     871 self._log.info_rank(
#     872     f"{self._log_prefix} begin build of solver covariance",
#     873     comm=self._comm,
#     874 )
# --> 876 solver_cov = CovarianceAndHits(
#     877     pixel_dist=self.binning.pixel_dist,
#     878     covariance=self.solver_cov_name,
#     879     hits=self.solver_hits_name,
#     880     rcond=self.solver_rcond_name,
#     881     det_data_units=self._det_data_units,
#     882     det_mask=self._save_det_mask,
#     883     det_flags=self.solver_flags,
#     884     det_flag_mask=255,
#     885     pixel_pointing=solve_pixels,
#     886     stokes_weights=solve_weights,
#     887     noise_model=self.binning.noise_model,
#     888     rcond_threshold=self.solve_rcond_threshold,
#     889     sync_type=self.binning.sync_type,
#     890     save_pointing=self.binning.full_pointing,
#     891 )
#     893 solver_cov.apply(self._data, detectors=self._detectors)
#     895 self._memreport.prefix = "After constructing covariance and hits"
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/mapmaker_utils/mapmaker_utils.py:1126, in CovarianceAndHits.__init__(self, **kwargs)
#    1125 def __init__(self, **kwargs):
# -> 1126     super().__init__(**kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/ops/operator.py:19, in Operator.__init__(self, **kwargs)
#      18 def __init__(self, **kwargs):
# ---> 19     super().__init__(**kwargs)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/traits.py:275, in TraitConfig.__init__(self, **kwargs)
#     273 def __init__(self, **kwargs):
#     274     self._accel_stack = list()
# --> 275     super().__init__(**kwargs)
#     276     if self.name is None:
#     277         self.name = self.__class__.__qualname__
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/traitlets/traitlets.py:1355, in HasTraits.__init__(self, *args, **kwargs)
#    1353 for key, value in kwargs.items():
#    1354     if self.has_trait(key):
# -> 1355         setattr(self, key, value)
#    1356         changes[key] = Bunch(
#    1357             name=key,
#    1358             old=None,
#    (...)
#    1361             type="change",
#    1362         )
#    1363     else:
#    1364         # passthrough args that don't set traits to super
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/traitlets/traitlets.py:690, in TraitType.set(self, obj, value)
#     689 def set(self, obj: HasTraits, value: S) -> None:
# --> 690     new_value = self._validate(obj, value)
#     691     assert self.name is not None
#     692     try:
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/traitlets/traitlets.py:722, in TraitType._validate(self, obj, value)
#     720     return value
#     721 if hasattr(self, "validate"):
# --> 722     value = self.validate(obj, value)
#     723 if obj._cross_validation_lock is False:
#     724     value = self._cross_validate(obj, value)
#
# File ~/.conda/envs/toastdev/lib/python3.9/site-packages/toast/traits.py:168, in Unit.validate(self, obj, value)
#     166         return None
#     167     else:
# --> 168         raise TraitError(
#     169             f"Attempt to set trait {self.name} to None, while allow_none=False"
#     170         )
#     171 try:
#     172     # Can we construct a unit from this?
#     173     return u.Unit(value)
#
# TraitError: Attempt to set trait det_data_units to None, while allow_none=False

# %%
#for detdata in ["full"]:
#    binner.det_data=detdata
#    mapmaker.binning= binner
#    mapmaker.det_data=detdata
#    mapmaker.output_dir = './'+detdata
#    mapmaker.apply(data)

#binner.det_data = 'noise'
#mapmaker_noise = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix,name = 'Mapmaker_noise',iter_max = 20)
#mapmaker_noise.det_data = 'noise'
#mapmaker_noise.output_dir = './noise'
#
#mapmaker_noise.apply(data)
#
#mapmakers_dict = {}

# %% [markdown]
# Monte Carlo mode in MapMaker

# %%
#mapmakers_dict['mapmaker_noise']
#
#mapmakers_dict = {}
#
#for detdata in ["signal", "noise", "atmosphere", "contamination", "full"]:
#    binner.det_data=detdata
#    mapmakers_dict['mapmaker_'+detdata] = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix,name = 'Mapmaker_'+detdata)
#    mapmakers_dict['mapmaker_'+detdata].det_data = detdata
#    mapmakers_dict['mapmaker_'+detdata].output_dir = './'+detdata
#    mapmakers_dict['mapmaker_'+detdata].apply(data)
#
#mapmaker_signal
#
#binner.det_data = 'signal'
#mapmaker_signal = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix,name = 'Mapmaker_signal')
#mapmaker_signal.det_data = 'signal'
##mapmaker_signal.apply(data)
#
#mapmaker_signal.apply(data)
#
#mapmaker.apply(data)
#
#mapmaker_signal.output_dir
#
#binner.det_data = 'noise'
#mapmaker_noise = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix,name = 'Mapmaker_noise')
#mapmaker_noise.det_data = 'noise'
#mapmaker_noise.apply(data)
#
#binner.det_data = 'atmosphere'
#mapmaker_atmosphere = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix,name = 'Mapmaker_atmosphere')
#mapmaker_atmosphere.det_data = 'atmosphere'
#mapmaker_atmosphere.apply(data)
#
#
#binner.det_data = 'contamination'
#mapmaker_contamination = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix,name = 'Mapmaker_contamination')
#mapmaker_contamination.det_data = 'contamination'
#
#mapmaker_contamination.apply(data)
#
#
#binner.det_data = 'total'
#mapmaker_total = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix,name = 'Mapmaker_total')
#mapmaker_total.det_data = 'total'
#
#mapmaker_total.apply(data)
#
#mapmakers_dict = {}
#
#for detdata in ["signal", "noise", "atmosphere", "contamination", "total"]:
#    binner.det_data=detdata
#    mapmakers_dict['mapmaker_'+detdata] = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix,name = 'Mapmaker_'+detdata)
#    mapmakers_dict['mapmaker_'+detdata].det_data = detdata
#
#detdata = 'noise'
#binner.det_data=detdata
#mapmakers_dict['mapmaker_'+detdata] = toast.ops.MapMaker(binning = binner, template_matrix=template_matrix,name = 'Mapmaker_'+detdata)
#mapmakers_dict['mapmaker_'+detdata].det_data = detdata
#
#mapmakers_dict['mapmaker_noise']
#
#
#
#for detdata in ["signal", "noise", "atmosphere", "contamination", "total"]:
#    mapmakers_dict['mapmaker_'+detdata].apply(data)

# %%
os.listdir('signal')
# Out:
# ['MapMaker_rcond.fits',
#  'MapMaker_cov.fits',
#  'MapMaker_map.fits',
#  'MapMaker_hits.fits',
#  'MapMaker_binmap.fits']

# %%
maps = {}
for detdata in ["signal", "noise", "atmosphere", "contamination", "full"]:
    maps['hitmap_'+detdata] = hp.read_map(detdata+"/MapMaker_hits.fits", dtype = float)
    maps['covmap_'+detdata] = hp.read_map(detdata+"/MapMaker_cov.fits", dtype = float)
    maps['map_'+detdata] = hp.read_map(detdata+"/MapMaker_map.fits", dtype = float)
    maps['binmap_'+detdata] = hp.read_map(detdata+"/MapMaker_binmap.fits", dtype = float)
    maps['rcondmap_'+detdata] = hp.read_map(detdata+"/MapMaker_rcond.fits", dtype = float)

# %%
hp.mollview(maps['hitmap_signal']-maps['hitmap_full'])

# %% [markdown]
# We have retrieved 5 flavours :
# 1. Detector noise
# 2. Atmosphere
# 3. Sky signal (CMB)
# 4. Contamination (atmosphere+noise)
# 5. Full
#
# and we want to check if everything has been linear

# %%
map_full_reconstruc = maps['map_noise']+maps['map_signal']+maps['map_atmosphere']

# %%
map_conta_signal = maps['map_signal']+maps['map_contamination']

# %%
m = maps['hitmap_signal']
diff_map = map_full_reconstruc -maps['map_full']
diff_map[m==0] = hp.UNSEEN

# %%
hp.mollview(diff_map, #min = -2e-7,max =7e-7, 
            title = r'$(m_{atm}+m_{noise}+m_{CMB})-m_{full}$')

# %%
import numpy.linalg as lalg

rel_del = lalg.norm(map_full_reconstruc -maps['map_full'])/lalg.norm(maps['map_full'])

# %%
print(rel_del)
# Out:
# 0.0006403811935699899

# %%
m = hp.read_map("MapMaker_hits.fits", dtype = float)
m[m==0] = hp.UNSEEN
hp.mollview(m, title =  "Hitmap")

# %%
hit_mask = np.array(np.where(m<=0))[0]
mask = np.ones(m.shape,dtype = np.float64)

# %%
mask.shape

# %%
mask[hit_mask] = 0

# %%
hp.mollview(mask, title = 'Mask associated to hits')

# %%
apodized_mask = np.clip(hp.smoothing(mask, fwhm=np.radians(10)), 0, None)
hp.mollview(apodized_mask, title = 'Apodized mask')

# %%
m_atm = hp.read_map("MapMaker_map.fits", dtype = float, field = None)
#m_atm -=mean_atm*mask
#m_atm[:] *= apodized_mask
#m_atm[:,hit_mask] = hp.UNSEEN

# %%
m_atm.shape

# %%
hp.mollview(m_atm[0], title =  "Noise + Atmosphere I map")

# %%
hp.mollview(m_atm[2], title =  "Noise + Atmosphere U polarization map")

# %%
hp.mollview(m_atm[1], title =  "Noise + Atmosphere Q polarization map")

# %%
cls_atm = hp.anafast(m_atm, lmax=lmax,use_pixel_weights=True)

# %%
cls_atm.shape

# %%
l_arr = np.arange(0,lmax+1)
l_arr.shape

# %%
hit_mask.shape

# %%
sky_fraction = 1-(len(hit_mask) / len(mask))
print(f"The map covers {sky_fraction:.1%} of the sky")

# %%
dls_atm = cls_atm[:]*l_arr*(l_arr+1)/(2*np.pi)

# %%
plt.plot(l_arr, dls_atm[0]/sky_fraction,'.',label = r'$D_{\ell}^{TT}$')
plt.plot(l_arr, dls_atm[1]/sky_fraction,'.', label = r'$D_{\ell}^{EE}$')
plt.plot(l_arr, dls_atm[2]/sky_fraction,'.', label = r'$D_{\ell}^{BB}$')
plt.xlabel('$\ell$')
plt.ylabel('$\mu K_{CMB}^2$')
plt.legend(loc = 'best')
plt.xscale('log')
plt.yscale('log')
plt.title('Noise + atmosphere')
plt.show()
